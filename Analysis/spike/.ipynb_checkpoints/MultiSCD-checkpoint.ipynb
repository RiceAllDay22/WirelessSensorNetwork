# %% [markdown]
# # SCD Multiplexer Example

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import glob

# %%
user = 'adria'
os.chdir('C:\\Users\\'+str(user)+'\\Desktop\\')
data = pd.read_csv('SCD_Multi_9-18.csv', header = None)

# %%
x = data[0]
y_1 = data[1]
y_2 = data[2]
baseline = data[3]

# %%
plt.plot(x, y_1, 'r')
plt.plot(x, y_2, 'b')
plt.plot(x, baseline, 'g-')
plt.show()

# %% [markdown]
# # Long Term ASC Analysis

# %%
user = 'adria'
subfolder = 'SCD_ASC_9-4'
os.chdir('C:\\Users\\'+str(user)+'\\Desktop\\'+str(subfolder))
data = pd.read_csv('SCD-WeekLong3.csv', header = None)

# %%
x = data[0]
y_1 = data[1]
plt.plot(x, y_1, 'r')
plt.show()
print(len(x))
# Out:
# 58172

# %%
(215317+29283+58172)/3600/24
# Out:
# 3.504305555555556
