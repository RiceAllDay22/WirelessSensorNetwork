# %% [markdown]
# # Adriann Liceralde

# %% [markdown]
# ## Part 1: Import Data

# %%
#Import Packages
getwd()
library(openair,   warn.conflicts = FALSE)
library(lubridate, warn.conflicts = FALSE)
# Out:
# [1] "C:/Users/adria/Desktop/Repo/WirelessSensorNetwork/Analysis/spike"

# %%
#Import Data File
rm(list=ls())

setwd('C:/Users/adria/Desktop/Repo/WirelessSensorNetwork/Data/V All')
#mydata_pri <- read.csv('C-2021-07-06-Pri.csv', header = TRUE, fileEncoding = 'UTF-8-BOM')
#mydata_sec <- read.csv('C-2021-07-06-Sec.csv', header = TRUE, fileEncoding = 'UTF-8-BOM')

# %%
mydata_pri <- import('C-2021-07-06-Pri.csv', date.format = '%m/%d/%Y %H:%M')
mydata_sec <- import('C-2021-07-06-Sec.csv', date.format = '%m/%d/%Y %H:%M')
# Out:
# ï»¿unixtime       date1       date2          ws          wd         co2
#   "integer"   "POSIXct"    "POSIXt"   "numeric"   "integer"   "integer"
#        temp
#   "integer"
# ï»¿unixtime       date1       date2          ws          wd         co2
#   "integer"   "POSIXct"    "POSIXt"   "numeric"   "integer"   "integer"
#        temp
#   "integer"

# %% [markdown]
# ## Part 2: Analyze Data

# %%
mydata_pri
# Out:
#       ï»¿unixtime date                ws   wd  co2 temp
# 1     1625604925  2021-07-06 20:55:00 1.34  83 419 41
# 2     1625604928  2021-07-06 20:55:00 1.68  66 467 41
# 3     1625604931  2021-07-06 20:55:00 2.01  76 502 41
# 4     1625604934  2021-07-06 20:55:00 2.35  74 488 41
# 5     1625604937  2021-07-06 20:55:00 2.35  69 466 41
# 6     1625604940  2021-07-06 20:55:00 2.01  80 448 41
# 7     1625604943  2021-07-06 20:55:00 2.01  86 455 41
# 8     1625604946  2021-07-06 20:55:00 3.02  86 449 41
# 9     1625604949  2021-07-06 20:55:00 3.35  91 444 41
# 10    1625604952  2021-07-06 20:55:00 3.02  82 415 41
# 11    1625604955  2021-07-06 20:55:00 2.35  99 465 41
# 12    1625604958  2021-07-06 20:55:00 1.34  91 519 41
# 13    1625604961  2021-07-06 20:56:00 1.34  89 370 41
# 14    1625604964  2021-07-06 20:56:00 2.35 117 431 42
# 15    1625604967  2021-07-06 20:56:00 3.02 121 377 42
# 16    1625604970  2021-07-06 20:56:00 2.35 119 390 42
# 17    1625604973  2021-07-06 20:56:00 2.35 121 398 42
# 18    1625604976  2021-07-06 20:56:00 2.68 117 390 42
# 19    1625604979  2021-07-06 20:56:00 2.68 118 386 42
# 20    1625604982  2021-07-06 20:56:00 2.68 116 396 42
# 21    1625604985  2021-07-06 20:56:00 2.68  74 410 42
# 22    1625604988  2021-07-06 20:56:00 2.68 125 415 42
# 23    1625604991  2021-07-06 20:56:00 3.69 117 420 42
# 24    1625604994  2021-07-06 20:56:00 5.03 119 419 42
# 25    1625604997  2021-07-06 20:56:00 4.02 116 396 42
# 26    1625605000  2021-07-06 20:56:00 5.36  46 383 42
# 27    1625605003  2021-07-06 20:56:00 5.70  67 352 42
# 28    1625605006  2021-07-06 20:56:00 7.04  65 350 41
# 29    1625605009  2021-07-06 20:56:00 5.70  39 395 41
# 30    1625605012  2021-07-06 20:56:00 3.69  21 397 41
# ...   ...         ...                 ...  ... ... ...
# 50936 1625757730  2021-07-08 15:22:00 0    42  432 34
# 50937 1625757733  2021-07-08 15:22:00 0    39  432 34
# 50938 1625757736  2021-07-08 15:22:00 0    40  430 34
# 50939 1625757739  2021-07-08 15:22:00 0    40  429 34
# 50940 1625757742  2021-07-08 15:22:00 0    39  428 34
# 50941 1625757745  2021-07-08 15:22:00 0    41  427 34
# 50942 1625757748  2021-07-08 15:22:00 0    39  427 34
# 50943 1625757751  2021-07-08 15:22:00 0    39  425 34
# 50944 1625757754  2021-07-08 15:22:00 0    40  424 34
# 50945 1625757757  2021-07-08 15:22:00 0    40  425 34
# 50946 1625757760  2021-07-08 15:22:00 0    42  425 34
# 50947 1625757763  2021-07-08 15:22:00 0    39  423 34
# 50948 1625757766  2021-07-08 15:22:00 0    40  424 34
# 50949 1625757769  2021-07-08 15:22:00 0    39  424 34
# 50950 1625757772  2021-07-08 15:22:00 0    39  424 34
# 50951 1625757775  2021-07-08 15:22:00 0    42  425 34
# 50952 1625757778  2021-07-08 15:22:00 0    39  425 34
# 50953 1625757781  2021-07-08 15:23:00 0    39  425 34
# 50954 1625757784  2021-07-08 15:23:00 0    40  428 34
# 50955 1625757787  2021-07-08 15:23:00 0    39  429 34
# 50956 1625757790  2021-07-08 15:23:00 0    42  426 34
# 50957 1625757793  2021-07-08 15:23:00 0    39  426 34
# 50958 1625757796  2021-07-08 15:23:00 0    40  427 34
# 50959 1625757799  2021-07-08 15:23:00 0    39  427 34
# 50960 1625757802  2021-07-08 15:23:00 0    40  429 34
# 50961 1625757805  2021-07-08 15:23:00 0    42  430 34
# 50962 1625757808  2021-07-08 15:23:00 0    40  429 34
# 50963 1625757811  2021-07-08 15:23:00 0    39  429 34
# 50964 1625757814  2021-07-08 15:23:00 0    39  428 34
# 50965 1625757817  2021-07-08 15:23:00 0    40  429 34

# %%
timePlot(mydata_pri, pollutant = 'co2')
timePlot(mydata_sec, pollutant = 'co2')
# Out:
# plot without title
# plot without title

# %%
timePlot(mydata_pri, pollutant = 'temp')
timePlot(mydata_sec, pollutant = 'temp')
# Out:
# plot without title
# plot without title

# %% [markdown]
# # Primary Node

# %%
polarPlot(mydata_pri, pollutant = 'co2', stati = 'cpf', percentile = c(0,10))
polarPlot(mydata_pri, pollutant = 'co2', stati = 'cpf', percentile = c(10,20))
polarPlot(mydata_pri, pollutant = 'co2', stati = 'cpf', percentile = c(20,30))
polarPlot(mydata_pri, pollutant = 'co2', stati = 'cpf', percentile = c(30,40))
polarPlot(mydata_pri, pollutant = 'co2', stati = 'cpf', percentile = c(40,50))
polarPlot(mydata_pri, pollutant = 'co2', stati = 'cpf', percentile = c(50,60))
polarPlot(mydata_pri, pollutant = 'co2', stati = 'cpf', percentile = c(60,70))
polarPlot(mydata_pri, pollutant = 'co2', stati = 'cpf', percentile = c(70,80))
polarPlot(mydata_pri, pollutant = 'co2', stati = 'cpf', percentile = c(80,90))
polarPlot(mydata_pri, pollutant = 'co2', stati = 'cpf', percentile = c(90,100))
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
#start_point = 10000
#end_point   = 20000

#mysubdata_pri = subset(mydata_pri,
#                       (as.numeric(rownames(mydata_pri)) > start_point) & (as.numeric(rownames(mydata_pri)) < end_point),
#                       select = c(date, wd, ws, co2))

#timePlot(mysubdata_pri, pollutant = 'co2')

# %%
#windRose(mydata_pri, angle = 22.5)
#percentileRose(mydata_pri, pollutant = 'co2')
#polarPlot(mydata_pri, pollutant = 'co2')
#polarPlot(mydata_pri, pollutant = 'co2', stati = 'cpf', percentile = c(80,90))
#polarPlot(mydata_pri, pollutant = 'co2', stati = 'cpf', percentile = c(90,100))

# %% [markdown]
# # Secondary Node

# %%
polarPlot(mydata_sec, pollutant = 'co2', stati = 'cpf', percentile = c(0,10))
polarPlot(mydata_sec, pollutant = 'co2', stati = 'cpf', percentile = c(10,20))
polarPlot(mydata_sec, pollutant = 'co2', stati = 'cpf', percentile = c(20,30))
polarPlot(mydata_sec, pollutant = 'co2', stati = 'cpf', percentile = c(30,40))
polarPlot(mydata_sec, pollutant = 'co2', stati = 'cpf', percentile = c(40,50))
polarPlot(mydata_sec, pollutant = 'co2', stati = 'cpf', percentile = c(50,60))
polarPlot(mydata_sec, pollutant = 'co2', stati = 'cpf', percentile = c(60,70))
polarPlot(mydata_sec, pollutant = 'co2', stati = 'cpf', percentile = c(70,80))
polarPlot(mydata_sec, pollutant = 'co2', stati = 'cpf', percentile = c(80,90))
polarPlot(mydata_sec, pollutant = 'co2', stati = 'cpf', percentile = c(90,100))
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
