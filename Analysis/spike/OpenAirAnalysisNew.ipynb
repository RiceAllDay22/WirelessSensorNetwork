# %% [markdown]
# # Adriann Liceralde

# %% [markdown]
# ## Part 1: Import Data

# %%
#Import Packages
getwd()
library(openair,   warn.conflicts = FALSE)
library(lubridate, warn.conflicts = FALSE)
# Out:
# [1] "C:/Users/adria/Desktop/Repo/WirelessSensorNetwork/Analysis/spike"

# %%
#Import Data File
rm(list=ls())

setwd('C:/Users/adria/Desktop/Repo/WirelessSensorNetwork/Data/V All')
#mydata_pri <- read.csv('C-2021-07-06-Pri.csv', header = TRUE, fileEncoding = 'UTF-8-BOM')
#mydata_sec <- read.csv('C-2021-07-06-Sec.csv', header = TRUE, fileEncoding = 'UTF-8-BOM')

# %%
mydata_pri <- import('C-2021-07-12-Pri.csv', date.format = '%m/%d/%Y %H:%M')
mydata_sec <- import('C-2021-07-17-Sec.csv', date.format = '%m/%d/%Y %H:%M')
# Out:
# ï»¿unixtime       date1       date2          ws          wd         co2
#   "integer"   "POSIXct"    "POSIXt"   "numeric"   "integer"   "integer"
#        temp          V7          V8
#   "integer"   "logical"   "integer"
# ï»¿unixtime       date1       date2          ws          wd         co2
#   "integer"   "POSIXct"    "POSIXt"   "numeric"   "integer"   "integer"
#        temp
#   "integer"

# %% [markdown]
# ## Part 2: Analyze Data

# %%
mydata_pri
# Out:
#       ï»¿unixtime date                ws   wd  co2 temp V7  V8
# 1     1626112597  2021-07-12 17:56:00 0.00 11  672 47   NA          NA
# 2     1626112600  2021-07-12 17:56:00 0.00 24  535 47   NA  1626394003
# 3     1626112603  2021-07-12 17:56:00 0.34 25  467 47   NA          NA
# 4     1626112606  2021-07-12 17:56:00 0.00 26  465 47   NA          NA
# 5     1626112609  2021-07-12 17:56:00 0.34 11  460 47   NA          NA
# 6     1626112612  2021-07-12 17:56:00 0.00 11  459 47   NA          NA
# 7     1626112615  2021-07-12 17:56:00 0.00 10  460 47   NA          NA
# 8     1626112618  2021-07-12 17:56:00 0.34 11  453 47   NA          NA
# 9     1626112621  2021-07-12 17:57:00 0.00 11  429 47   NA          NA
# 10    1626112624  2021-07-12 17:57:00 0.00 10  416 47   NA          NA
# 11    1626112627  2021-07-12 17:57:00 0.00 12  427 47   NA          NA
# 12    1626112630  2021-07-12 17:57:00 0.34 11  435 47   NA          NA
# 13    1626112633  2021-07-12 17:57:00 0.00 11  403 47   NA          NA
# 14    1626112636  2021-07-12 17:57:00 0.34 10  398 47   NA          NA
# 15    1626112639  2021-07-12 17:57:00 0.00 10  438 47   NA          NA
# 16    1626112642  2021-07-12 17:57:00 0.00 12  384 47   NA          NA
# 17    1626112645  2021-07-12 17:57:00 0.34 10  396 48   NA          NA
# 35040 1626393976  2021-07-16 00:06:00 0.67 167 337 35   NA  NA
# 35041 1626393979  2021-07-16 00:06:00 0.34 169 332 35   NA  NA
# 35042 1626393982  2021-07-16 00:06:00 0.67 130 337 35   NA  NA
# 35043 1626393985  2021-07-16 00:06:00 0.67 130 338 35   NA  NA
# 35044 1626393988  2021-07-16 00:06:00 1.01 208 342 35   NA  NA
# 35045 1626393991  2021-07-16 00:06:00 1.01 191 335 35   NA  NA
# 35046 1626393994  2021-07-16 00:06:00 1.01 193 335 35   NA  NA
# 35047 1626393997  2021-07-16 00:06:00 0.67  81 341 35   NA  NA
# 35048 1626394000  2021-07-16 00:06:00 1.34  86 345 35   NA  NA
# 35049 1626394003  2021-07-16 00:06:00 2.01 115 349 35   NA  NA

# %%
timePlot(mydata_pri, pollutant = 'co2')
timePlot(mydata_sec, pollutant = 'co2')
# Out:
# plot without title
# plot without title

# %%
timePlot(mydata_pri, pollutant = 'temp')
timePlot(mydata_sec, pollutant = 'temp')

# %% [markdown]
# # Primary Node

# %%
polarPlot(mydata_pri, pollutant = 'co2', stati = 'cpf', percentile = c(0,10))
polarPlot(mydata_pri, pollutant = 'co2', stati = 'cpf', percentile = c(10,20))
polarPlot(mydata_pri, pollutant = 'co2', stati = 'cpf', percentile = c(20,30))
polarPlot(mydata_pri, pollutant = 'co2', stati = 'cpf', percentile = c(30,40))
polarPlot(mydata_pri, pollutant = 'co2', stati = 'cpf', percentile = c(40,50))
polarPlot(mydata_pri, pollutant = 'co2', stati = 'cpf', percentile = c(50,60))
polarPlot(mydata_pri, pollutant = 'co2', stati = 'cpf', percentile = c(60,70))
polarPlot(mydata_pri, pollutant = 'co2', stati = 'cpf', percentile = c(70,80))
polarPlot(mydata_pri, pollutant = 'co2', stati = 'cpf', percentile = c(80,90))
polarPlot(mydata_pri, pollutant = 'co2', stati = 'cpf', percentile = c(90,100))
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
#start_point = 10000
#end_point   = 20000

#mysubdata_pri = subset(mydata_pri,
#                       (as.numeric(rownames(mydata_pri)) > start_point) & (as.numeric(rownames(mydata_pri)) < end_point),
#                       select = c(date, wd, ws, co2))

#timePlot(mysubdata_pri, pollutant = 'co2')

# %%
#windRose(mydata_pri, angle = 22.5)
#percentileRose(mydata_pri, pollutant = 'co2')
#polarPlot(mydata_pri, pollutant = 'co2')
#polarPlot(mydata_pri, pollutant = 'co2', stati = 'cpf', percentile = c(80,90))
#polarPlot(mydata_pri, pollutant = 'co2', stati = 'cpf', percentile = c(90,100))

# %% [markdown]
# # Secondary Node

# %%
polarPlot(mydata_sec, pollutant = 'co2', stati = 'cpf', percentile = c(0,10))
polarPlot(mydata_sec, pollutant = 'co2', stati = 'cpf', percentile = c(10,20))
polarPlot(mydata_sec, pollutant = 'co2', stati = 'cpf', percentile = c(20,30))
polarPlot(mydata_sec, pollutant = 'co2', stati = 'cpf', percentile = c(30,40))
polarPlot(mydata_sec, pollutant = 'co2', stati = 'cpf', percentile = c(40,50))
polarPlot(mydata_sec, pollutant = 'co2', stati = 'cpf', percentile = c(50,60))
polarPlot(mydata_sec, pollutant = 'co2', stati = 'cpf', percentile = c(60,70))
polarPlot(mydata_sec, pollutant = 'co2', stati = 'cpf', percentile = c(70,80))
polarPlot(mydata_sec, pollutant = 'co2', stati = 'cpf', percentile = c(80,90))
polarPlot(mydata_sec, pollutant = 'co2', stati = 'cpf', percentile = c(90,100))
